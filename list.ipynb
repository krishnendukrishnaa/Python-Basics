# %%
a=[3,5,7,8,1,10]
print(a[1])
# Out:
# 5

# %%
a=[4,5]
b=[2,3]
a.append(b)
print(a)
# Out:
# [4, 5, [2, 3]]

# %%
a=[1,2,3,4,5]
sum=0
for i in a:
  sum=sum+i
print(sum)
# Out:
# 15

# %%
a=[4,6,1]
max(a)
# Out:
# 6

# %%
a=[2,8,0,3]
min(a)
# Out:
# 0

# %%
a=[1,2]
if(len(a)==0):
  print("List is Empty")
else:
  print("List is not empty")
# Out:
# List is not empty

# %%
a=[1,2,"j"]
b=a.copy()
print(b)
# Out:
# [1, 2, 'j']

# %%
a=[3,5,8,4,9]
print(a)
for i in a:
  if(i%2==1):
    print(i)
# Out:
# [3, 5, 8, 4, 9]
# 3
# 5
# 9

# %%
a=[3,4]
b=[7,6.7,'k']
print(a+b)
# Out:
# [3, 4, 7, 6.7, 'k']

# %%
a=list("welcome to")
print(a)
# Out:
# ['w', 'e', 'l', 'c', 'o', 'm', 'e', ' ', 't', 'o']

# %%
a=[1,"m",3.5,6]
a.extend([2,5])
print(a)
# Out:
# [1, 'm', 3.5, 6, 2, 5]

# %%
a=[3,5,6,11.6,10,9,1]
print(min(a))
# Out:
# 1

# %%
print(max(a))
# Out:
# 11.6

# %%
a=[6,7,1,3,1,0,4,1]
print(a.count(1))
# Out:
# 3

# %%
a=[2,4,5,6,]
print(a.index(5))
# Out:
# 2

# %%
a=[2,4,8,9,5]
a.reverse()
print(a)
# Out:
# [5, 9, 8, 4, 2]

# %%
a=[1,2,3,6,2,1]
b=set(a)
c=list(b)
print(c)
# Out:
# [1, 2, 3, 6]

# %%
a=[1,2,3,6,1,7,2,9,0,3,1]
b=set(a)
print(a)
a=list(b)
print(b)
# Out:
# [1, 2, 3, 6, 1, 7, 2, 9, 0, 3, 1]
# {0, 1, 2, 3, 6, 7, 9}

# %%
a=[2,3,4,1]
b=[9,7,8,2,1,6]
a=set(a)
b=set(b)
print(a.intersection(b))
# Out:
# {1, 2}
