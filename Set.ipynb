# %%
a={1,3,4,6,7,2,1,6,7}
print(a)
# Out:
# {1, 2, 3, 4, 6, 7}

# %%
a={}
print(a)
# Out:
# {}

# %%
a={1,"m",4,5,5,7}
a.add(3)
print(a)
# Out:
# {1, 3, 4, 5, 'm', 7}

# %%
a={2,5,6,7,8}
a.update({3,1})
print(a)
# Out:
# {1, 2, 3, 5, 6, 7, 8}

# %%
print(a)
a.pop()
print(a)
# Out:
# {1, 2, 3, 5, 6, 7, 8}
# {2, 3, 5, 6, 7, 8}

# %%
print(a)
a.clear()
print(a)
# Out:
# {2, 3, 5, 6, 7, 8}
# set()

# %%
a={4,5,6,7}
print(a)
a.remove(5)
print(a)
# Out:
# {4, 5, 6, 7}
# {4, 6, 7}

# %%
a={5,6,7,8,8,9,4}
b={1,0}
print(a.union(b))
# Out:
# {0, 1, 4, 5, 6, 7, 8, 9}

# %%
a={2,4,5,6,7}
b={5,6,2}
print(a.intersection(b))
# Out:
# {2, 5, 6}

# %%
a={2,4,5,6,7}
b={5,1}
z=a.difference(b)
print(z)
# Out:
# {2, 4, 6, 7}

# %%
a={2,4,5,6,7,8}
print(a)
# Out:
# {2, 4, 5, 6, 7, 8}

# %%
a={2,4,5,6,7,9}
a.remove(6)
print(a)
# Out:
# {2, 4, 5, 7, 9}

# %%
a={3,4,5,6,1,0}
a.add(2)
print(a)
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
a={3,4,5,6,2}
b={1,2,3}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a={2,4,5,6,7}
b={2,4,1}
print(a.intersection(b))
# Out:
# {2, 4}

# %%
print(a.difference(b))
# Out:
# {5, 6, 7}

# %%
a={2,4,5,6,7}
print(a)
a.clear()
print(a)
# Out:
# {2, 4, 5, 6, 7}
# set()

# %%
a={2,4,5,6}
len(a)
# Out:
# 4

# %%
a={2,4,5,6}
b={2,4,7,8}
print(a^b)
# Out:
# {5, 6, 7, 8}

# %%
a={2.3,4,'hi'}
b=a.copy()
print(b)
# Out:
# {2.3, 4, 'hi'}

# %%
a={2,3,4,5}
b={9,7,8}
if(a.intersection(b)):
  print(a.intersection(b))
else:
  print("No elements")
# Out:
# No elements

# %%
a={1,0,9,0,2,1,4,9,5}
for i in a:
  print(i)
# Out:
# 0
# 1
# 2
# 4
# 5
# 9

# %%
a=set("welcome")
for i in a:
  print(i)
# Out:
# c
# o
# l
# w
# e
# m

# %%
a={2,3}
b={2,3,4,6}
print(a.issubset(b))
# Out:
# True
