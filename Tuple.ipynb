# %%
a=(1,2)
print(a)
# Out:
# (1, 2)

# %%
b=a+(8,4)
print(b)
# Out:
# (1, 2, 8, 4)

# %%
a=(5,6,3,9,14,1.5,5)
print(a)
# Out:
# (5, 6, 3, 9, 14, 1.5, 5)

# %%
print(a[0:4])
# Out:
# (5, 6, 3, 9)

# %%
print(a[3:6])
# Out:
# (9, 14, 1.5)

# %%
print(a[::-1])
# Out:
# (5, 1.5, 14, 9, 3, 6, 5)

# %%
print(a[::-2])
# Out:
# (5, 14, 3, 5)

# %%
print(a[::-3])
# Out:
# (5, 9, 5)

# %%
print(a)
print(a[0:6:2])
# Out:
# (5, 6, 3, 9, 14, 1.5, 5)
# (5, 3, 14)

# %%
print(a)
print(a[-2:6])
# Out:
# (5, 6, 3, 9, 14, 1.5, 5)
# (1.5,)

# %%
print(a[1:-1])
# Out:
# (6, 3, 9, 14, 1.5)

# %%
print(a)
print(a[2:6])
# Out:
# (5, 6, 3, 9, 14, 1.5, 5)
# (3, 9, 14, 1.5)

# %%
print(a)
print(min(a))
# Out:
# (5, 6, 3, 9, 14, 1.5, 5)
# 1.5

# %%
print(max(a))
# Out:
# 14

# %%
a=(5, 6, 3, 9, 14, 1.5, 5)
print(a)
print(a.count(5))
# Out:
# (5, 6, 3, 9, 14, 1.5, 5)
# 2

# %%
a=(2,4,5)
print(a)
print(a.index(4))
# Out:
# (2, 4, 5)
# 1

# %%
a=tuple("hai")
print(a)
# Out:
# ('h', 'a', 'i')

# %%
a=(2,5,6,7,9)
print(a)
# Out:
# (2, 5, 6, 7, 9)

# %%
a=(2,2.3,"hi",3,"ok")
print(a)
# Out:
# (2, 2.3, 'hi', 3, 'ok')

# %%
a=(3,5,6,7,8,3,9)
print(a)
print(a[3])
# Out:
# (3, 5, 6, 7, 8, 3, 9)
# 7

# %%
a=(8,6,7,8,9)
b=a+(1,2)
print(b)
# Out:
# (8, 6, 7, 8, 9, 1, 2)

# %%
a=tuple("Hello")
print(a)
# Out:
# ('H', 'e', 'l', 'l', 'o')

# %%
a=tuple([2,4,5,6])
print(a)
# Out:
# (2, 4, 5, 6)

# %%
a=(2,5,7,8,9,0)
print(len(a))
# Out:
# 6

# %%
a=(2,4,5,6,7)
print(a[::-1])
# Out:
# (7, 6, 5, 4, 2)

# %%
a=(2,4,5)
b,c,d=a
b=1
a=(b,c,d)
print(a)
# Out:
# (1, 4, 5)
