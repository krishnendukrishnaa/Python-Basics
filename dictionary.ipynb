# %%
d={}
print(d)
# Out:
# {}

# %%
d={'name':'Ram','age':40,'age':24}
print(d)
# Out:
# {'name': 'Ram', 'age': 24}

# %%
d.update({'gender':'m'})
print(d)
# Out:
# {'name': 'Ram', 'age': 24, 'gender': 'm'}

# %%
print(d)
d.pop('gender')
print(d)
# Out:
# {'name': 'Ram', 'age': 24, 'gender': 'm'}
# {'name': 'Ram', 'age': 24}

# %%
d={'name':'ram','age':23}
d.update({'age':24})
print(d)
# Out:
# {'name': 'ram', 'age': 24}

# %%
d.update({'gender':'M'})
print(d)
# Out:
# {'name': 'ram', 'age': 24, 'gender': 'M'}

# %%
d={'a':20,'b':50,'c':60}
sum=0
for i in d.values():
  sum=sum+i
print(sum)
# Out:
# 130

# %%
d={'a':1,'b':2,'c':3}
a=1
for i in d:
  a=a*d[i]
print(a)
# Out:
# 6

# %%
d={'a':100,'b':200,'c':300}
sum=0
for i in d.values():
  sum=sum+i
print(sum)
# Out:
# 600

# %%
d={'a':300,'b':2,'c':3}
a=1
for i in d:
  a=a*d[i]
print(a)
# Out:
# 1800

# %%
print(len(d))
# Out:
# 3

# %%
a=dict(a=3,b='r')
print(a)
# Out:
# {'a': 3, 'b': 'r'}
