# %%
a=10
a
# Out:
# 10

# %%
print(a)
# Out:
# 10

# %%
print("Hai")
# Out:
# Hai

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b=11
print(a+b)
# Out:
# 21

# %%
c=a+b
print(c)
# Out:
# 21

# %%
a=input("enter your number")
print(a)
# Out:
# enter your number2
# 2

# %%
a=int(input("enter your value"))
# Out:
# enter your value6

# %%
print(a)
# Out:
# 6

# %%
a=int(input("enter your value"))
print(a)
# Out:
# enter your value6
# 6

# %%
a=10
if(a>0):
  print("Positive")
else:
  print("Negative")
# Out:
# Positive

# %%
a=10
if(a>0):
  print("Positive")
elif(a<0):
  print("Negative")
else:
  print("Zero")
# Out:
# Positive

# %%
a=10
b=5
c=8
if(a>b>c):
  print(a)
elif(b>a>c):
  print(b)
else:
  print(c)
# Out:
# 8

# %%
a=10
b=5
c=8
if(a>b)or(a>c):
  print(a)
elif(b>a)or(b>c):
  print(b)
else:
  print(c)
# Out:
# 10

# %%
a=6
b=7
print(a+b)
# Out:
# 13

# %%
a=0
if(a>0):
  print("positive")
elif(a<0):
  print("Negative")
else:
  print("Zero")
# Out:
# Zero

# %%
a=5
if(a%2==0):
  print("Even")
else:
  print("Odd")
# Out:
# Odd

# %%
a=6
if(a%2==0):
  print("Even")
else:
  print("Odd")
# Out:
# Even

# %%
a=int(input("Enter the mark in english "))
b=int(input("Enter the mark in Malayalam "))
c=int(input("Enter the mark in Hindi "))
d=int(input("Enter the mark in science "))
e=int(input("Enter the mark in English "))
avg=(a+b+c+d+e)/5
print(avg)
if((avg>=90)and(avg<=100)):
  print("A+")
elif((avg>=80)and(avg<=90)):
  print("A")
elif((avg>=70)and(avg<=80)):
  print("B+")
elif((avg>=60)and(avg<=70)):
  print("B")
elif((avg>=50)and(avg<=60)):
  print("C+")
elif((avg>=40)and(avg<=50)):
  print("C")
else:
  print("failed")
# Out:
# Enter the mark in english 66
# Enter the mark in Malayalam 66
# Enter the mark in Hindi 88
# Enter the mark in science 98
# Enter the mark in English 78
# 79.2
# B+

# %%
a=10
b=5
c=7
if(a>b)and(a>c):
  print(a)
elif(b>a)and(b>c):
  print(b)
else:
  print(c)
# Out:
# 10

# %%
a=9
b=8
c=3
if(a<b)and(a<c):
  print(a)
elif(b<a)and(b<c):
  print(b)
else:
  print(c)
# Out:
# 3

# %%
a=8
b=1
c=10
if(a<b)and(a<c):
  print(a)
elif(b<a)and(b<c):
  print(b)
else:
  print(c)
# Out:
# 1

# %%
a=6
b=10
c=9
if(a>b)and(a>c):
  print(a)
elif(b>a)and(b>c):
  print(b)
else:
  print(c)
# Out:
# 10

# %%
a=int(input("Enter the value1 = "))
b=int(input("Enter the value2 = "))
c=a+b
print(c)
avg=c/2
print(avg)
# Out:
# Enter the value1 = 6
# Enter the value2 = 9
# 15
# 7.5

# %%
for i in range(1,16):
  if(i%5==0):
    print(i)
# Out:
# 5
# 10
# 15

# %%
a=int(input("Amount "))
d=(a/100)*10
print(d)
c=a-d
print(c)
# Out:
# Amount 1500
# 150.0
# 1350.0

# %%
a=int(input("Enter your age  "))
if(a<18):
  print("can't vote")
elif(a>=18)and(a>=25):
  print("can vote and contest")
else:
  print("eligible ")
# Out:
# Enter your age  25
# can vote and contest

# %%
a=int(input("enter the year "))
if(a%4==0):
  print("Leap year")
else:
    print("Not leap year")
# Out:
# enter the year 2020
# Leap year

# %%
a=int(input("Enter the month "))
if(a==1):
  print("January")
elif(a==2):
  print("February")
elif(a==3):
  print("March")
elif(a==4):
  print("April")
elif(a==5):
  print("May")
elif(a==6):
  print("June")
elif(a==7):
  print("July")
elif(a==8):
  print("August")
elif(a==9):
  print("Septemper")
elif(a==10):
  print("October")
elif(a==11):
  print("November")
else:
  print("December")
# Out:
# Enter the month 5
# May

# %%
a=input("Enter the color  ")
if(a=="V")or(a=="v"):
   print("Violet")
elif(a=="I")or(a=="i"):
  print("Indigo")
elif(a=="B")or(a=="b"):
  print("Blue")
elif(a=="G")or(a=="g"):
  print("Green")
elif(a=="Y")or(a=="y"):
  print("Yellow")
elif(a=="O")or(a=="o"):
  print("Orange")
elif(a=="R")or(a=="r"):
  print("Red")
else:
  print("Invalid")
# Out:
# Enter the color  y
# Yellow

# %%
s="welcome"
print(s)
# Out:
# welcome

# %%
print(len(s))
# Out:
# 7

# %%
print(s[0])
# Out:
# w

# %%
print(s[6])
# Out:
# e

# %%
print(s[-1])
# Out:
# e

# %%
print(s[-3])
# Out:
# o

# %%
s="welcome all"
print(s)
# Out:
# welcome all

# %%
print(s.capitalize())
# Out:
# Welcome all

# %%
print(s.title())
# Out:
# Welcome All

# %%
print(s.upper())
# Out:
# WELCOME ALL

# %%
print(s.lower())
# Out:
# welcome all

# %%
print(s.istitle())
# Out:
# False

# %%
print(s.isupper())
# Out:
# False

# %%
print(s.islower())
# Out:
# True

# %%
print(s.find("all"))
# Out:
# 8

# %%
print(s.find("welcome"))
# Out:
# 0

# %%
print(s.find("Hi"))
# Out:
# -1

# %%
print(s.index("all"))
# Out:
# 8

# %%
print(s.index("Hi"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-188-8a752079f7c8> in <cell line: 1>()
# ----> 1 print(s.index("Hi"))
#
# ValueError: substring not found

# %%
print(s.count("w"))
# Out:
# 1

# %%
print(s.count("e"))
# Out:
# 2

# %%
print(s.replace("welcome","hi"))
# Out:
# hi all

# %%
print(s.isalpha())
# Out:
# False

# %%
print(s.isdigit())
# Out:
# False

# %%
 print(s.split())
# Out:
# ['welcome', 'all']

# %%
d="."
print(d.join(s))
# Out:
# w.e.l.c.o.m.e. .a.l.l

# %%
li=[]
print(li)
# Out:
# []

# %%
li=[1,2,'hi',4.5]
print(l)
# Out:
# [1, 2, 'hi', 4.5, 6]

# %%
a=[1,2,3,"hi",1.2]
print(a)
# Out:
# [1, 2, 3, 'hi', 1.2]

# %%
a=[1,2,3,"hi",1.2]
a.append(6)
print(a)
# Out:
# [1, 2, 3, 'hi', 1.2, 6]

# %%
a.extend([8,7])
print(a)
# Out:
# [1, 2, 3, 'hi', 1.2, 6, 8, 7]

# %%
a=[1, 2, 3, 'hi', 1.2, 6, 8, 7]
a.insert(2,10)
print(a)
# Out:
# [1, 2, 10, 3, 'hi', 1.2, 6, 8, 7]

# %%
del a[1]
print(a)
# Out:
# [1, 10, 3, 'hi', 1.2, 6, 8, 7]

# %%
a=[1, 10, 3, 'hi', 1.2, 6, 8, 7]
a.remove(3)
print(a)
# Out:
# [1, 10, 'hi', 1.2, 6, 8, 7]

# %%
a=[1, 10, 3, 'hi', 1.2, 6, 8, 7]
a.pop()
print(a)
# Out:
# [1, 10, 3, 'hi', 1.2, 6, 8]

# %%
a=[1, 10, 3, 'hi', 1.2, 6, 8, 7]
print(a)
a.clear()
print(a)
# Out:
# [1, 10, 3, 'hi', 1.2, 6, 8, 7]
# []

# %%
a=[1, 10, 3, 'hi', 1.2, 6, 8, 7]
print(a)
del a
print(a)
# Out:
# [1, 10, 3, 'hi', 1.2, 6, 8, 7]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-220-354ba995e406> in <cell line: 4>()
#       2 print(a)
#       3 del a
# ----> 4 print(a)
#
# NameError: name 'a' is not defined

# %%
s="hello septemper"
print(s)
print(len(s))

# %%
print(s.count("e"))

# %%
s="hello septemper"
print(s)
print(s.upper())

# %%
s="Hi September"
print(s)
print(s.lower())

# %%
s="kerala"
print(len(s))
